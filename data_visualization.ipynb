# %%
import matplotlib.pyplot as plt

# %%
x = [3,6,12,23,46,67,78,88,90,105]
y = [12,45,56,67,69,71,79,88,94,111]
z = [23,34,44,44,47,59,61,69,78,96]

# %%
import pylab   # import 
plt.figure(figsize=(16,9))
plt.subplot(3,1,1)
plt.plot(x,y,color='purple')
plt.subplot(3,1,2)
plt.plot(x,z,color='green')
plt.subplot(3,1,3)
plt.title('Third')
plt.grid()
plt.plot(y,z,color='red')
pylab.savefig('graph.png')

# %%
data = [56,54,53,11,55,48,98,76,55,45,45,33,12,68,45,66]

# %%
plt.hist(data,bins=[0,20,40,60,80,100])
# Out:
# (array([2., 1., 9., 3., 1.]),
#  array([  0,  20,  40,  60,  80, 100]),
#  <a list of 5 Patch objects>)
