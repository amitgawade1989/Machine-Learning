# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/Datasets/EDA/2015.csv')

# %%
data.shape
# Out:
# (158, 12)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#          Country  ... Dystopia Residual
# 0    Switzerland  ...           2.51738
# 1        Iceland  ...           2.70201
# 2        Denmark  ...           2.49204
# 3         Norway  ...           2.46531
# 4         Canada  ...           2.45176
# ..           ...  ...               ...
# 153       Rwanda  ...           0.67042
# 154        Benin  ...           1.63328
# 155        Syria  ...           0.32858
# 156      Burundi  ...           1.83302
# 157         Togo  ...           1.56726
#
# [158 rows x 12 columns]

# %%
data.head(20)
# Out:
#                  Country  ... Dystopia Residual
# 0            Switzerland  ...           2.51738
# 1                Iceland  ...           2.70201
# 2                Denmark  ...           2.49204
# 3                 Norway  ...           2.46531
# 4                 Canada  ...           2.45176
# 5                Finland  ...           2.61955
# 6            Netherlands  ...           2.46570
# 7                 Sweden  ...           2.37119
# 8            New Zealand  ...           2.26425
# 9              Australia  ...           2.26646
# 10                Israel  ...           3.08854
# 11            Costa Rica  ...           3.17728
# 12               Austria  ...           2.53320
# 13                Mexico  ...           3.60214
# 14         United States  ...           2.51011
# 15                Brazil  ...           3.26001
# 16            Luxembourg  ...           1.96961
# 17               Ireland  ...           1.97570
# 18               Belgium  ...           2.41484
# ...

# %%
data.tail(10)
# Out:
#           Country  ... Dystopia Residual
# 148          Chad  ...           1.94296
# 149        Guinea  ...           1.99172
# 150   Ivory Coast  ...           1.41723
# 151  Burkina Faso  ...           1.46494
# 152   Afghanistan  ...           1.95210
# 153        Rwanda  ...           0.67042
# 154         Benin  ...           1.63328
# 155         Syria  ...           0.32858
# 156       Burundi  ...           1.83302
# 157          Togo  ...           1.56726
#
# [10 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.describe()
# Out:
#        Happiness Rank  Happiness Score  ...  Generosity  Dystopia Residual
# count      158.000000       158.000000  ...  158.000000         158.000000
# mean        79.493671         5.375734  ...    0.237296           2.098977
# std         45.754363         1.145010  ...    0.126685           0.553550
# min          1.000000         2.839000  ...    0.000000           0.328580
# 25%         40.250000         4.526000  ...    0.150553           1.759410
# 50%         79.500000         5.232500  ...    0.216130           2.095415
# 75%        118.750000         6.243750  ...    0.309883           2.462415
# max        158.000000         7.587000  ...    0.795880           3.602140
#
# [8 rows x 10 columns]

# %%
def remove_outlier(col):
  sorted(col)
  q1,q2 = col.quantile([0.25,0.75])
  IQR = q2-q1
  lr = q1-(1.5*IQR)
  ub = q2+(1.5*IQR)
  return lr,ub

# %%
lscore,upperscore = remove_outlier(data['Trust (Government Corruption)'])
data['Trust (Government Corruption)'] = np.where(data['Trust (Government Corruption)']>upperscore,upperscore,data['Trust (Government Corruption)'])
data['Trust (Government Corruption)'] = np.where(data['Trust (Government Corruption)']<lscore,lscore,data['Trust (Government Corruption)'])

# %%
data.boxplot(column='Trust (Government Corruption)')

# %%
data.shape
# Out:
# (158, 12)

# %%
#Normalization/standardization

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# %%
data['Happiness Score'] = sc.fit_transform(data[['Happiness Score']])

# %%
data.head()
# Out:
#        Country          Region  ...  Generosity  Dystopia Residual
# 0  Switzerland  Western Europe  ...     0.29678            2.51738
# 1      Iceland  Western Europe  ...     0.43630            2.70201
# 2      Denmark  Western Europe  ...     0.34139            2.49204
# 3       Norway  Western Europe  ...     0.34699            2.46531
# 4       Canada   North America  ...     0.45811            2.45176
#
# [5 rows x 12 columns]

# %%
#pairwise correlation 

data.corr()
# Out:
#                                Happiness Rank  ...  Dystopia Residual
# Happiness Rank                       1.000000  ...          -0.521999
# Happiness Score                      1.000000  ...          -0.521999
# Standard Error                       0.158516  ...           0.083981
# Economy (GDP per Capita)            -0.785267  ...           0.040059
# Family                              -0.733644  ...           0.148117
# Health (Life Expectancy)            -0.735613  ...           0.018979
# Freedom                             -0.556886  ...           0.062783
# Trust (Government Corruption)       -0.386326  ...          -0.006807
# Generosity                          -0.160142  ...          -0.101301
# Dystopia Residual                   -0.521999  ...           1.000000
#
# [10 rows x 10 columns]

# %%
import seaborn as sns
sns.heatmap(data.corr(),annot=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/drive/MyDrive/Datasets/EDA/StudentsPerformance.csv')

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
data['gender'].value_counts().plot(kind = 'bar',title = "Gender of students")

# %%
data['race/ethnicity'].value_counts().plot(kind='bar')

# %%
data['race/ethnicity'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
data['lunch'].value_counts().plot(kind = "bar")

# %%
data.boxplot()

# %%
data.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
import seaborn as sns
sns.displot(data['math score'])
print(data['math score'].skew())
# Out:
# -0.27893514909431694

# %%
data.corr()
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(data.corr(),annot=True)

# %%
sns.regplot(x = data['reading score'],y=data['writing score'])

# %%
sns.relplot(x = 'reading score',y='writing score',hue='gender',data =data)

# %%
sns.pairplot(data = data,hue='gender')

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/EDA/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  ...  origin                   car name
# 0    18.0          8  ...       1  chevrolet chevelle malibu
# 1    15.0          8  ...       1          buick skylark 320
# 2    18.0          8  ...       1         plymouth satellite
# 3    16.0          8  ...       1              amc rebel sst
# 4    17.0          8  ...       1                ford torino
# ..    ...        ...  ...     ...                        ...
# 393  27.0          4  ...       1            ford mustang gl
# 394  44.0          4  ...       2                  vw pickup
# 395  32.0          4  ...       1              dodge rampage
# 396  28.0          4  ...       1                ford ranger
# 397  31.0          4  ...       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
df.describe()
# Out:
#               mpg   cylinders  ...  model year      origin
# count  398.000000  398.000000  ...  398.000000  398.000000
# mean    23.514573    5.454774  ...   76.010050    1.572864
# std      7.815984    1.701004  ...    3.697627    0.802055
# min      9.000000    3.000000  ...   70.000000    1.000000
# 25%     17.500000    4.000000  ...   73.000000    1.000000
# 50%     23.000000    4.000000  ...   76.000000    1.000000
# 75%     29.000000    8.000000  ...   79.000000    2.000000
# max     46.600000    8.000000  ...   82.000000    3.000000
#
# [8 rows x 7 columns]

# %%
print("Skewness:",df['mpg'].skew())
# Out:
# Skewness: 0.45706634399491913

# %%
sns.displot(df['mpg'])

# %%
#skewness

# %%
#Encoding
newdata = pd.get_dummies(df,columns=['origin'])

# %%
newdata
# Out:
#       mpg  cylinders  displacement  ... origin_1  origin_2  origin_3
# 0    18.0          8         307.0  ...        1         0         0
# 1    15.0          8         350.0  ...        1         0         0
# 2    18.0          8         318.0  ...        1         0         0
# 3    16.0          8         304.0  ...        1         0         0
# 4    17.0          8         302.0  ...        1         0         0
# ..    ...        ...           ...  ...      ...       ...       ...
# 393  27.0          4         140.0  ...        1         0         0
# 394  44.0          4          97.0  ...        0         1         0
# 395  32.0          4         135.0  ...        1         0         0
# 396  28.0          4         120.0  ...        1         0         0
# 397  31.0          4         119.0  ...        1         0         0
#
# [398 rows x 11 columns]
